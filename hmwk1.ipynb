# %% [markdown]
# # MATH 515 Lab 1

# %% [markdown]
# ## Problem 1

# %%
import os
os.getcwd()
# Out:
# '/home/thsiao3/notebooks'

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
# Problem 1 
for k in range(6):
    x = np.linspace(0, 4*np.pi, 2^(k+2)+1)
    y = np.sin(x)
    plt.subplot(2, 3, k+1)
    plt.plot(x, y)
    plt.scatter(x, y)
    plt.axis((0 - 1, 4 * np.pi + 1, -1.5, 1.5))

# %% [markdown]
# ## Problem 2

# %%
# Problem 2
def displayCircles(r):
    """Accepts as input a vector r with positive entries, and plots circles of radius r(i) centered 
    at the origin on the same axes. Defaults to plot single circle with radius 1"""
